# %%
# !pip install -q -U google-genai

# %%
# 구글 제미나이 AI
from google import genai

client = genai.Client(api_key="AIzaSyAqPPBxlMlwJx27hFBvHguXNe5RUXYwuUM") # GEMINI_API_KEY # AIzaSyAqPPBxlMlwJx27hFBvHguXNe5RUXYwuUM

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="오늘 부산의 일출은 몇시야?"
)
print(response.text)
# Out:
# 오늘 부산의 일출은 **오전 6시 10분**입니다.

# %%
# 구글 제미나이 AI
from google import genai

client = genai.Client(api_key="AIzaSyAqPPBxlMlwJx27hFBvHguXNe5RUXYwuUM") # GEMINI_API_KEY # AIzaSyAqPPBxlMlwJx27hFBvHguXNe5RUXYwuUM

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="오늘 부산의 일출은 몇시야?"
)
print(response.text)
# Out:
# 오늘 부산의 일출 시각은 **오전 5시 23분**입니다.

# %%
# # 구글 제미나이 AI 더 심화
# from google import genai
# from dotenv import load_dotenv
# import os

# load_dotenv() # .env 파일로드
# data = os.getenv("GEMINI_API_KEY")

# def gai(que):
#     client = genai.Client(api_key = data)
#     response = client.models.generate_content(
#     model="gemini-2.5-flash-lite", contents = que)
#     print(response.text)

# if __name__="__main__":
#     for n in range(5):
#         agi(input("질문하세요."))

# %%
# gai("한국의 봄이란")

# %%
import myai

# %%
myai.gai("서울의 gps는?")
# Out:
# 서울의 GPS 좌표는 대략적으로 다음과 같습니다.
#
# *   **위도 (Latitude):** 약 **37.5665° N**
# *   **경도 (Longitude):** 약 **126.9780° E**
#
# 이 좌표는 서울의 중심부를 나타내며, 실제 서울 시내의 각 지점마다 미세한 차이가 있을 수 있습니다.
#
# 더 정확한 GPS 정보를 원하시면, 특정 지역이나 건물의 주소를 알려주시면 해당 위치의 GPS 좌표를 찾아드릴 수 있습니다.

# %%
myai.gai("부산 해운대의 gps는?")
# Out:
# 부산 해운대의 GPS 좌표는 대략 다음과 같습니다.
#
# *   **위도 (Latitude):** 35.1594° N
# *   **경도 (Longitude):** 129.1161° E
#
# 이 좌표는 해운대의 중심부를 나타내며, 해운대의 특정 장소 (예: 해운대 해수욕장, 해운대역 등)에 따라 약간의 차이가 있을 수 있습니다.
#
# 보다 정확한 위치를 찾고 싶으시다면, Google 지도, 네이버 지도 등 지도 앱에서 "해운대"를 검색하시면 다양한 지점을 확인하고 해당 지점의 GPS 좌표를 얻으실 수 있습니다.

# %%
# 구글 제미나이 AI
from google import genai
contents = input("질문:")
client = genai.Client(api_key="GEMINI_API_KEY") # GEMINI_API_KEY # AIzaSyAqPPBxlMlwJx27hFBvHguXNe5RUXYwuUM

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents=contents
)
print(response.text)
# Out:
# 질문: 지금 부산의 온도는?
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[4], line 6
#       3 contents = input("질문:")
#       4 client = genai.Client(api_key="GEMINI_API_KEY") # GEMINI_API_KEY # AIzaSyAqPPBxlMlwJx27hFBvHguXNe5RUXYwuUM
# ----> 6 response = client.models.generate_content(
#       7     model="gemini-2.5-flash-lite", contents=contents
#       8 )
#       9 print(response.text)
#
# File ~/venv/lib/python3.12/site-packages/google/genai/models.py:5621, in Models.generate_content(self, model, contents, config)
#    5619 while remaining_remote_calls_afc > 0:
#    5620   i += 1
# -> 5621   response = self._generate_content(
#    5622       model=model, contents=contents, config=parsed_config
#    5623   )
#    5625   function_map = _extra_utils.get_function_map(parsed_config)
#    5626   if not function_map:
#
# ...

# %%
# 클로저 *   함수를 리턴

def calc():
    a = 3
    b = 5
    def mul_add(x):
        return a * x + b
    return mul_add

# %%
c = calc()
c(2)
# Out:
# 11
