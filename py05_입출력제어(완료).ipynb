# %% [markdown]
# # 입출력제어

# %% [markdown]
# ## 파일생성 및 추가하기

# %%
# !pwd
# Out:
# /home/kys/data

# %%
f = open("새파일이에요.txt","w")
f.close()

# %% [markdown]
# <table style="float:left">
# <thead>
# <tr>
# <th>파일열기모드</th>
# <th>설명</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>r</td>
# <td>읽기 모드: 파일을 읽기만 할 때 사용한다.</td>
# </tr>
# <tr>
# <td>w</td>
# <td>쓰기 모드: 파일에 내용을 쓸 때 사용한다.</td>
# </tr>
# <tr>
# <td>a</td>
# <td>추가 모드: 파일의 마지막에 새로운 내용을 추가할 때 사용한다.</td>
# </tr>
# </tbody>
# </table>

# %%
# 리눅스에서
f = open("/home/kys/test.txt","w")
f.close()

# %%
f = open("새파일이에요.txt","w")

for i in range(0,20,2):
    f.write(str(i)+"\n")
f.close()

# %%
import requests as req

f = open("즐겨찾기종목.txt","a")
url = "https://finance.naver.com/sise/sise_market_sum.naver"
ori = req.get(url).text
code = ['005930','000270','005380','012450','068270']

def finance(code = '005930'):
    start_title = ori.find(f'<a href="/item/main.naver?code={code}" class="tltle">')
    ori1 = ori[start_title : start_title + 70].replace(f'<a href="/item/main.naver?code={code}" class="tltle">','').replace('</a></td>','').replace('</a></td','').replace('\n','').strip()
    ori2 = ori[start_title + 70 : start_title + 105].replace('<td class="number">','').replace('</td>','').replace('>','').strip()
    print("종목:",ori1)
    print("가격:",ori2)
    result = "종목:" + ori1 + "\n" + "가격:" + ori2 + "\n"
    f.write(result)
    
for x in code:
    finance(x)
f.close()
# Out:
# 종목: 삼성전자
# 가격: 178,400
# 종목: 기아
# 가격: 164,700
# 종목: 현대차
# 가격: 504,000
# 종목: 한화에어로스페이스
# 가격: 1,127,000
# 종목: 셀트리온
# 가격: 238,500

# %% [markdown]
# ## 파일읽어오기

# %%
# readline 함수 이용하기

# %%
# 응용2
import requests as req
url = "https://api4.binance.com/api/v3/ticker/price?symbol=BTCUSDT"
res = req.get(url).text
btc = res[29:34]
won = str(int(btc)*1450)
# print(won)
print(((won[-12:-8] + "억") if won[-12:-8] else ""), won[-8:-4]+ '만',won[-4:]+ '원')
# Out:
#  9742만 6950원

# %%
import time as tt
f = open("./즐겨찾기종목.txt","r")

while 1:
    line = f.readline().strip() # 
    if not line : break
    print(line, end="\r")
    tt.sleep(1)
    print(" "*15, end="\r") # 지우는 역할
f.close()

# %%
f = open("./즐겨찾기종목.txt","r")
print(f.readlines())
f.close()
# Out:
# ['종목:삼성전자\n', '가격:178,400\n', '종목:기아\n', '가격:164,700\n', '종목:현대차\n', '가격:504,000\n', '종목:한화에어로스페이스\n', '가격:1,127,000\n', '종목:셀트리온\n', '가격:238,500\n']

# %%
f = open("./즐겨찾기종목.txt","r")
print(f.read())
f.close()
# Out:
# 종목:삼성전자
# 가격:178,400
# 종목:기아
# 가격:164,700
# 종목:현대차
# 가격:504,000
# 종목:한화에어로스페이스
# 가격:1,127,000
# 종목:셀트리온
# 가격:238,500

# %%
f = open("./즐겨찾기종목.txt","r")
for line in f:
    print(line, end="")
f.close()
# Out:
# 종목:삼성전자
# 가격:178,400
# 종목:기아
# 가격:164,700
# 종목:현대차
# 가격:504,000
# 종목:한화에어로스페이스
# 가격:1,127,000
# 종목:셀트리온
# 가격:238,500
# 종목:홍길동
# 가격:9,999,999

# %%
f = open("./즐겨찾기종목.txt","r")
print(f)
f.close()
# Out:
# <_io.TextIOWrapper name='./즐겨찾기종목.txt' mode='r' encoding='UTF-8'>

# %%
f = open("./즐겨찾기종목.txt","a")
f.write(f"종목:홍길동\n가격:9,999,999")
f.close()

# %% [markdown]
# ## With문 으로 읽고, 쓰기

# %%
with open("./즐겨찾기종목.txt","r") as f:
    print(f.closed)
    print(f.read())
    print(f.closed)
print(f.closed)
# Out:
# False
# 종목:삼성전자
# 가격:178,400
# 종목:기아
# 가격:164,700
# 종목:현대차
# 가격:504,000
# 종목:한화에어로스페이스
# 가격:1,127,000
# 종목:셀트리온
# 가격:238,500
# 종목:홍길동
# 가격:9,999,999
# False
# True

# %%
# 함수스코프
def my_function():
    func_var = "함수 안의 변수"

my_function()
# print(func_var)

# %% [markdown]
# ![image.png](attachment:b99bdd0a-c463-47d4-90ca-23269da796e1.png)

# %%
with open("./즐겨찾기종목.txt","r") as f:
    data = f.read()
print(data)
# Out:
# 종목:삼성전자
# 가격:178,400
# 종목:기아
# 가격:164,700
# 종목:현대차
# 가격:504,000
# 종목:한화에어로스페이스
# 가격:1,127,000
# 종목:셀트리온
# 가격:238,500
# 종목:홍길동
# 가격:9,999,999

# %% [markdown]
# ## 프로그램의 입출력

# %%
import sys
args = sys.argv
for i in args:
    print(i)
# Out:
# /home/kys/venv/lib/python3.12/site-packages/ipykernel_launcher.py
# -f
# /home/kys/.local/share/jupyter/runtime/kernel-29540935-0d0a-4780-b37f-6875407ce0d7.json

# %%
# !python3 args_test.py 12 34 56
# Out:
# args_test.py
# 12
# 34
# 56

# %%
# %%sh
# python3 args_test.py 12 34 56
# python3 btc.py
# Out:
# args_test.py
# 12
# 34
# 56
#  9592만 4750원

# %%
# %%sh
# cat <<'end'> sys2.py
# import sys
# args = sys.argv[1:]
# for i in args:
#     print(i.upper(), end=' ')
# end
# python3 sys2.py life is too short, you need python
# Out:
# LIFE IS TOO SHORT, YOU NEED PYTHON

# %%
name = input("당신의 이름은?")
age = input("당신의 나이는?")
with open('./test_note.txt','a') as f:
    f.write(name +" " + age+"\n")
# Out:
# 당신의 이름은? 홍길동
# 당신의 나이는? 22
