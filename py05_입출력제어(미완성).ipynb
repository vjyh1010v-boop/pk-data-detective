# %% [markdown]
# ## With문으로 읽고, 쓰기

# %%
with open() as f:
    print(f.closed)
    print(f.read())
    print(f.closed)
print(f.closed)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 with open() as f:
#       2     print(f.closed)
#       3     print(f.read())
#
# TypeError: open() missing 1 required positional argument: 'file'

# %%
# newfile.py
f = open("새파일.txt", 'w')
f.close()

# %%
for x in range(3):
    print(x)
# Out:
# 0
# 1
# 2

# %%
x
# Out:
# 2

# %% [markdown]
# ## 프로그램의 입출력

# %%
import sys
args = sys.argv
for i in args:
    print(i)
# Out:
# /home/jyh/venv/lib/python3.12/site-packages/ipykernel_launcher.py
# -f
# /home/jyh/.local/share/jupyter/runtime/kernel-6c80dfcd-ea7a-4529-b711-1fed50a1f256.json

# %%
# !ls
# Out:
#  args_test.py			      'py03_제어문(주윤희).ipynb'
#  func1.py			      'py04_함수(주윤희).ipynb'
#  func2.py			       py05_입출력제어.ipynb
# 'py01_파이썬기초자료형(완료).ipynb'   'python web.py'
# 'py02_주요자료형(완료-주윤희).ipynb'   test.txt
#  py02_주요자료형_a.ipynb	       test2.txt
# 'py03_제어문(완료).ipynb'	       새파일.txt

# %%
# !python3 args_test.py 12 34 56
# Out:
# args_test.py
# 12
# 34
# 56

# %%
# %%sh
# python3 args_test.py 12 34 56
# python3 btc.py
# Out:
# args_test.py
# 12
# 34
# 56
# python3: can't open file '/home/jyh/data/btc.py': [Errno 2] No such file or directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 get_ipython().run_cell_magic('sh', '', 'python3 args_test.py 12 34 56\npython3 btc.py\n')
#
# File ~/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2572, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2570 with self.builtin_trap:
#    2571     args = (magic_arg_s, cell)
# -> 2572     result = fn(*args, **kwargs)
#    2574 # The code below prevents the output from being displayed
#    2575 # when using magics with decorator @output_can_be_silenced
#    2576 # when the last Python token in the expression is a ';'.
#    2577 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# sys2.py
import sys
args = sys.argv[1:]
for i in args:
    print(i.upper(), end=' ')
# Out:
# -F /HOME/JYH/.LOCAL/SHARE/JUPYTER/RUNTIME/KERNEL-6C80DFCD-EA7A-4529-B711-1FED50A1F256.JSON

# %%
# %%sh
# python3 sys2.py

# %%
with open('./','a') as f:

# %%
name = input("당신의 이름은?")
age = input("당신의 나이는?")
with open('./test_not.txt','a') as f:
    f.write(name + " " + age + "\n")
print("입력 되었습니다.")
# Out:
# 당신의 이름은? 주윤희
# 당신의 나이는? 30
# 입력 되었습니다.
