# %% [markdown]
# # 주요 자료형

# %% [markdown]
# ## 리스트 자료형

# %%
# 리스트 만들기
odd = [1,3,5,7,9]

# %%
# 리스트 중요한 점. 순서 !! index!!
a = []
b = [1, 2, 3]
c = ['Life', 'is', 'too', 'short']
d = [1, 2, 'Life', 'is']
e = [1, 2, ['Life', 'is']]

# %%
s = "spring"
s[0]
a = [11,22,33,44,55]
print(a[0] + a[3])
# Out:
# 55

# %%
a= 'banana'
print(id(a))
b = a
b = 'kiwi'
print(id(b))
print(a)
print(b)
# Out:
# 124337223682400
# 124337223683696
# banana
# kiwi

# %%
aa = [11,22,33]
print(id(aa))
bb = aa
print(id(bb))
print(aa)
print(bb)
# Out:
# 124336837763840
# 124336837763840
# [11, 22, 33]
# [11, 22, 33]

# %%
# 배열 초기화
cc = []
print(cc, type(cc))
dd = list()
print(dd, type(dd))
# Out:
# [] <class 'list'>
# [] <class 'list'>

# %%
# 2중배열
li = [1,2,3,4,5,[11,22,33]]
print(li)
# Out:
# [1, 2, 3, 4, 5, [11, 22, 33]]

# %%
print(li[0])
print(li[4])
print(li[-1])
print(li[-1][1])
# Out:
# 1
# 5
# [11, 22, 33]
# 22

# %%
# 삼중리스트
# a = [1, 2, 3 ['a', 'b', 'c', ['oR', 'Life', 'is']]
# 'Life' !!

a = [1, 2, 3,['a', 'b', 'c', ['ok', 'Life', 'is']]]
print(a[-1][-1][-2])
# Out:
# Life

# %%
#리스트의 슬라이싱
a = [11,22,33,44,55]
print(a[:2])
print(a[1:2])
print(a[3:])
# Out:
# [11, 22]
# [22]
# [44, 55]

# %%
# 중첩된 리스트에서 슬라이싱 하기
a = [1, 2, ['0', '1', 'a', 'b', 'c'], 4, 5]
# ['a', 'b', 'c']

print(a)
# Out:
# [1, 2, ['0', '1', 'a', 'b', 'c'], 4, 5]

# %% [markdown]
# ### 응용문제

# %%
# 장바구니 초기화
bag = [] # bag = list()

# %% [markdown]
# ## 튜플 자료형

# %%
t1 = ()
t2 = (1,)  # *
t3 = (1, 2, 3)
t4 = 1, 2, 3  # *
t5 = ('a', 'b', ('ab', 'cd'))

# %%
# 주의점
t2 = (4324,)
print(type(t2))
t4 = 123,
print(type(t4))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
# 튜플 요솟값 삭제
t1 = (1,2,'a','b')
# del t1[1]

# %% [markdown]
# **튜플은 요소 삭제 안됨**
# ![image.png](attachment:32cfb36c-d3df-41d5-86e1-948feddacc54.png)

# %%
t1 = (1,2,'a','b')
# t1[2] = 'apple'

# %% [markdown]
# **튜플은 요솟값 변경이 안됨**
# ![image.png](attachment:8e5fb5ce-c189-4088-8f5a-ea52a4237462.png)

# %%
# 인덱싱하기
t1 = (1, 2, 'a', 'b')
print(t1[0])
print(t1[3])
# Out:
# 1
# b

# %%
# 슬라이싱하기
t1 = 1, 2, 'a', 'b'
print(t1[1:])
# Out:
# (2, 'a', 'b')

# %%
# 튜플 곱하기
t2 = (3, 4)
t3 = t2 * 3
print(t3)
# Out:
# (3, 4, 3, 4, 3, 4)

# %%
# 튜플 더하기
t1 = (1, 2, 'a', 'b')
t2 = (3, 4)
t3 = t1 + t2
print(t3)
# Out:
# (1, 2, 'a', 'b', 3, 4)

# %%
# 튜플 길이 구하기
t1 = (1, 2, 'a', 'b')
print(len(t1))
# Out:
# 4

# %% [markdown]
# ## 딕셔너리 자료형

# %%
# 딕셔너리 초기화
dic0 = {}
print(dic0,type(dic0))
# Out:
# {} <class 'dict'>

# %% [markdown]
# <table>
# <thead>
# <tr>
# <th>key</th>
# <th>value</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>name</td>
# <td>pey</td>
# </tr>
# <tr>
# <td>phone</td>
# <td>010-9999-1234</td>
# </tr>
# <tr>
# <td>birth</td>
# <td>1118</td>
# </tr>
# </tbody>
# </table>

# %%
# 딕셔너리 만들기
dic0 = {2:"kiwi":,0:"banana",1:"apple",3:"orange"}
dic1 = {"name":"pey","phone":"010-9999-1234","birth":"1118"}
# Out:
#   Cell In[43], line 2
#     dic0 = {2:"kiwi":,0:"banana",1:"apple",3:"orange"}
#                     ^
# SyntaxError: invalid syntax

# %%
# 쌍추가
print(dic1)
dic1['address'] = "서울"
print(dic1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 print(dic1)
#       2 dic1['address'] = "서울"
#       3 print(dic1)
#
# NameError: name 'dic1' is not defined

# %%
# 문제
obj = {"김연아": "피겨스케이팅", "류현진": "야구", "손흥민": "축구", "귀도": "파이썬"}
# 변경 김연아 : 은퇴
# 추가 김연경 : 배구
# 삭제 : 귀도

obj["김연아"] = "은퇴"
obj["김연경"] = "배구"
del obj["귀도"]
print(obj)
# Out:
# {'김연아': '은퇴', '류현진': '야구', '손흥민': '축구', '김연경': '배구'}

# %%
# 주의사항
# key가 두개 이상이면 안된다.
a = {1: 'a', 1: 'b'}
print(a)
# key 값에는 리스트나 딕셔너리같은 mutable 형식이 되면 안된다. (튜플가능)
# a = {[1,2]:'hi'}
# key 값에 딕셔너리?
# a = {{[1:'hello'}:'hi'}
# Out:
# {1: 'b'}

# %% [markdown]
# **딕셔너리에 리스트를 키로사용한 경우**
#
# ![image.png](attachment:1aec82cb-4ba9-4bdc-bf00-8f37d6e533d9.png)

# %% [markdown]
# ### 딕셔너리 관련함수

# %%
# keys 키 리스트 만들기
a = {'name': 'pey', 'phone': '010-9999-1234', 'birth': '1118'}
ky = a.keys()
l_ky = list(ky)
print(ky,type(a),type(ky),type(l_ky),sep="\n")
# Out:
# dict_keys(['name', 'phone', 'birth'])
# <class 'dict'>
# <class 'dict_keys'>
# <class 'list'>

# %%
# values 값 리스트 만들기
a = {"name":"pey","phone":"010-9999-1234","birth":"1118"}
va= a.values()
l_va = list(va)
print(va,type(a),type(va),type(l_va),sep="\n")
# Out:
# dict_values(['pey', '010-9999-1234', '1118'])
# <class 'dict'>
# <class 'dict_values'>
# <class 'list'>

# %%
# items 키값쌍을 리스트안의 튜플로 만들기
a = {"name":"pey","phone":"010-9999-1234","birth":"1118"}
it= a.items()
l_it = list(it)
print(it,type(a),type(it),type(l_it),sep="\n")
# Out:
# dict_items([('name', 'pey'), ('phone', '010-9999-1234'), ('birth', '1118')])
# <class 'dict'>
# <class 'dict_items'>
# <class 'list'>

# %%
# clear 키값쌍ahen wldnrl
a = {"name":"pey","phone":"010-9999-1234","birth":"1118"}
print(a)
a.clear()
print(a)
# Out:
# {'name': 'pey', 'phone': '010-9999-1234', 'birth': '1118'}
# {}

# %%
# get 키로 값얻기
a = {"name":"pey","phone":"010-9999-1234","birth":"1118"}
print(a.get('ok'))
print(a.get('ok','없습니다.'))
# Out:
# None
# 없습니다.

# %%
# in 해당 키 값 조사하기 **
a = {"name":"pey","phone":"010-9999-1234","birth":"1118"}

print("name" in a)
print("phone" in a)
print("ok" in a)
# Out:
# True
# True
# False

# %%
# pop 가져와서 삭제하기
a = {"name":"pey","phone":"010-9999-1234","birth":"1118"}
pp = a.pop("phone")
print("꺼낸값:",pp)
print("남은값:",a)
# Out:
# 꺼낸값: 010-9999-1234
# 남은값: {'name': 'pey', 'birth': '1118'}

# %%
# 응용실습
import requests as r
url = "https://oapi.koreaexim.go.kr/site/program/financial/exchangeJSON?authkey=Rjimf3GvGZ9YOi7d2cF97UGGTndLmrd9&data=AP01"
result = r.get(url).json()
print(result)
# Out:
# [{'result': 1, 'cur_unit': 'AED', 'ttb': '391.18', 'tts': '399.09', 'deal_bas_r': '395.14', 'bkpr': '395', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '395', 'kftc_deal_bas_r': '395.14', 'cur_nm': '아랍에미리트 디르함'}, {'result': 1, 'cur_unit': 'AUD', 'ttb': '1,005.46', 'tts': '1,025.77', 'deal_bas_r': '1,015.62', 'bkpr': '1,015', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '1,015', 'kftc_deal_bas_r': '1,015.62', 'cur_nm': '호주 달러'}, {'result': 1, 'cur_unit': 'BHD', 'ttb': '3,810.84', 'tts': '3,887.83', 'deal_bas_r': '3,849.34', 'bkpr': '3,849', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '3,849', 'kftc_deal_bas_r': '3,849.34', 'cur_nm': '바레인 디나르'}, {'result': 1, 'cur_unit': 'BND', 'ttb': '1,128.8', 'tts': '1,151.61', 'deal_bas_r': '1,140.21', 'bkpr': '1,140', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '1,140', 'kftc_deal_bas_r': '1,140.21', 'cur_nm': '브루나이 달러'}, {'result': 1, 'cur_unit': 'CAD', 'ttb': '1,051.17', 'tts': '1,072.4', 'deal_bas_r': '1,061.79', 'bkpr': '1,061', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '1,061', 'kftc_deal_bas_r': '1,061.79', 'cur_nm': '캐나다 달러'}, {'result': 1, 'cur_unit': 'CHF', 'ttb': '1,849.02', 'tts': '1,886.37', 'deal_bas_r': '1,867.7', 'bkpr': '1,867', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '1,867', 'kftc_deal_bas_r': '1,867.7', 'cur_nm': '스위스 프랑'}, {'result': 1, 'cur_unit': 'CNH', 'ttb': '207.13', 'tts': '211.32', 'deal_bas_r': '209.23', 'bkpr': '209', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '209', 'kftc_deal_bas_r': '209.23', 'cur_nm': '위안화'}, {'result': 1, 'cur_unit': 'DKK', 'ttb': '227.16', 'tts': '231.75', 'deal_bas_r': '229.46', 'bkpr': '229', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '229', 'kftc_deal_bas_r': '229.46', 'cur_nm': '덴마아크 크로네'}, {'result': 1, 'cur_unit': 'EUR', 'ttb': '1,696.29', 'tts': '1,730.56', 'deal_bas_r': '1,713.43', 'bkpr': '1,713', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '1,713', 'kftc_deal_bas_r': '1,713.43', 'cur_nm': '유로'}, {'result': 1, 'cur_unit': 'GBP', 'ttb': '1,961.01', 'tts': '2,000.62', 'deal_bas_r': '1,980.82', 'bkpr': '1,980', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '1,980', 'kftc_deal_bas_r': '1,980.82', 'cur_nm': '영국 파운드'}, {'result': 1, 'cur_unit': 'HKD', 'ttb': '183.9', 'tts': '187.61', 'deal_bas_r': '185.76', 'bkpr': '185', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '185', 'kftc_deal_bas_r': '185.76', 'cur_nm': '홍콩 달러'}, {'result': 1, 'cur_unit': 'IDR(100)', 'ttb': '8.56', 'tts': '8.73', 'deal_bas_r': '8.65', 'bkpr': '8', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '8', 'kftc_deal_bas_r': '8.65', 'cur_nm': '인도네시아 루피아'}, {'result': 1, 'cur_unit': 'JPY(100)', 'ttb': '916.13', 'tts': '934.64', 'deal_bas_r': '925.39', 'bkpr': '925', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '925', 'kftc_deal_bas_r': '925.39', 'cur_nm': '일본 옌'}, {'result': 1, 'cur_unit': 'KRW', 'ttb': '0', 'tts': '0', 'deal_bas_r': '1', 'bkpr': '1', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '1', 'kftc_deal_bas_r': '1', 'cur_nm': '한국 원'}, {'result': 1, 'cur_unit': 'KWD', 'ttb': '4,703.5', 'tts': '4,798.53', 'deal_bas_r': '4,751.02', 'bkpr': '4,751', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '4,751', 'kftc_deal_bas_r': '4,751.02', 'cur_nm': '쿠웨이트 디나르'}, {'result': 1, 'cur_unit': 'MYR', 'ttb': '365.37', 'tts': '372.76', 'deal_bas_r': '369.07', 'bkpr': '369', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '369', 'kftc_deal_bas_r': '369.07', 'cur_nm': '말레이지아 링기트'}, {'result': 1, 'cur_unit': 'NOK', 'ttb': '148.54', 'tts': '151.55', 'deal_bas_r': '150.05', 'bkpr': '150', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '150', 'kftc_deal_bas_r': '150.05', 'cur_nm': '노르웨이 크로네'}, {'result': 1, 'cur_unit': 'NZD', 'ttb': '861.94', 'tts': '879.35', 'deal_bas_r': '870.65', 'bkpr': '870', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '870', 'kftc_deal_bas_r': '870.65', 'cur_nm': '뉴질랜드 달러'}, {'result': 1, 'cur_unit': 'SAR', 'ttb': ' ...

# %%
print(result,type(result))
# Out:
# [{'result': 1, 'cur_unit': 'AED', 'ttb': '391.18', 'tts': '399.09', 'deal_bas_r': '395.14', 'bkpr': '395', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '395', 'kftc_deal_bas_r': '395.14', 'cur_nm': '아랍에미리트 디르함'}, {'result': 1, 'cur_unit': 'AUD', 'ttb': '1,005.46', 'tts': '1,025.77', 'deal_bas_r': '1,015.62', 'bkpr': '1,015', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '1,015', 'kftc_deal_bas_r': '1,015.62', 'cur_nm': '호주 달러'}, {'result': 1, 'cur_unit': 'BHD', 'ttb': '3,810.84', 'tts': '3,887.83', 'deal_bas_r': '3,849.34', 'bkpr': '3,849', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '3,849', 'kftc_deal_bas_r': '3,849.34', 'cur_nm': '바레인 디나르'}, {'result': 1, 'cur_unit': 'BND', 'ttb': '1,128.8', 'tts': '1,151.61', 'deal_bas_r': '1,140.21', 'bkpr': '1,140', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '1,140', 'kftc_deal_bas_r': '1,140.21', 'cur_nm': '브루나이 달러'}, {'result': 1, 'cur_unit': 'CAD', 'ttb': '1,051.17', 'tts': '1,072.4', 'deal_bas_r': '1,061.79', 'bkpr': '1,061', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '1,061', 'kftc_deal_bas_r': '1,061.79', 'cur_nm': '캐나다 달러'}, {'result': 1, 'cur_unit': 'CHF', 'ttb': '1,849.02', 'tts': '1,886.37', 'deal_bas_r': '1,867.7', 'bkpr': '1,867', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '1,867', 'kftc_deal_bas_r': '1,867.7', 'cur_nm': '스위스 프랑'}, {'result': 1, 'cur_unit': 'CNH', 'ttb': '207.13', 'tts': '211.32', 'deal_bas_r': '209.23', 'bkpr': '209', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '209', 'kftc_deal_bas_r': '209.23', 'cur_nm': '위안화'}, {'result': 1, 'cur_unit': 'DKK', 'ttb': '227.16', 'tts': '231.75', 'deal_bas_r': '229.46', 'bkpr': '229', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '229', 'kftc_deal_bas_r': '229.46', 'cur_nm': '덴마아크 크로네'}, {'result': 1, 'cur_unit': 'EUR', 'ttb': '1,696.29', 'tts': '1,730.56', 'deal_bas_r': '1,713.43', 'bkpr': '1,713', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '1,713', 'kftc_deal_bas_r': '1,713.43', 'cur_nm': '유로'}, {'result': 1, 'cur_unit': 'GBP', 'ttb': '1,961.01', 'tts': '2,000.62', 'deal_bas_r': '1,980.82', 'bkpr': '1,980', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '1,980', 'kftc_deal_bas_r': '1,980.82', 'cur_nm': '영국 파운드'}, {'result': 1, 'cur_unit': 'HKD', 'ttb': '183.9', 'tts': '187.61', 'deal_bas_r': '185.76', 'bkpr': '185', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '185', 'kftc_deal_bas_r': '185.76', 'cur_nm': '홍콩 달러'}, {'result': 1, 'cur_unit': 'IDR(100)', 'ttb': '8.56', 'tts': '8.73', 'deal_bas_r': '8.65', 'bkpr': '8', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '8', 'kftc_deal_bas_r': '8.65', 'cur_nm': '인도네시아 루피아'}, {'result': 1, 'cur_unit': 'JPY(100)', 'ttb': '916.13', 'tts': '934.64', 'deal_bas_r': '925.39', 'bkpr': '925', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '925', 'kftc_deal_bas_r': '925.39', 'cur_nm': '일본 옌'}, {'result': 1, 'cur_unit': 'KRW', 'ttb': '0', 'tts': '0', 'deal_bas_r': '1', 'bkpr': '1', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '1', 'kftc_deal_bas_r': '1', 'cur_nm': '한국 원'}, {'result': 1, 'cur_unit': 'KWD', 'ttb': '4,703.5', 'tts': '4,798.53', 'deal_bas_r': '4,751.02', 'bkpr': '4,751', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '4,751', 'kftc_deal_bas_r': '4,751.02', 'cur_nm': '쿠웨이트 디나르'}, {'result': 1, 'cur_unit': 'MYR', 'ttb': '365.37', 'tts': '372.76', 'deal_bas_r': '369.07', 'bkpr': '369', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '369', 'kftc_deal_bas_r': '369.07', 'cur_nm': '말레이지아 링기트'}, {'result': 1, 'cur_unit': 'NOK', 'ttb': '148.54', 'tts': '151.55', 'deal_bas_r': '150.05', 'bkpr': '150', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '150', 'kftc_deal_bas_r': '150.05', 'cur_nm': '노르웨이 크로네'}, {'result': 1, 'cur_unit': 'NZD', 'ttb': '861.94', 'tts': '879.35', 'deal_bas_r': '870.65', 'bkpr': '870', 'yy_efee_r': '0', 'ten_dd_efee_r': '0', 'kftc_bkpr': '870', 'kftc_deal_bas_r': '870.65', 'cur_nm': '뉴질랜드 달러'}, {'result': 1, 'cur_unit': 'SAR', 'ttb': ' ...

# %%
# print(result,type(result))
print(result[-1]['cur_unit'],";",result[-1]['deal_bas_r'] + "원")
# Out:
# USD ; 1,451.2원

# %%
# 이전에 일어난 실시간 비트코인 BTC / USD 가격으로
# 실시간 환율을 계산하여
# 지금 비트코인 가격을 원화로 표시하시오.
# py 파일로 저장하여 python3로 실행할 수 있도록 하시요.

# %%
import requests as req
url = "https://api4.binance.com/api/v3/ticker/price?symbol=BTCUSDT"
res = req.get(url).text
btc = res[29:34]
print(btc)
print(res,";",res+"원")
# Out:
# 70628
# {"symbol":"BTCUSDT","price":"70628.89000000"} ; {"symbol":"BTCUSDT","price":"70628.89000000"}원

# %% [markdown]
# ## 집합 자료형

# %%
# 집합자료형 초기화
sl = set()
print(sl, type(sl))
# Out:
# set() <class 'set'>

# %%
# set 자료형 중복허용 안함
li = [1,2,3] *2 + [1,22,33]*3
print(li)
sl = set(li)
print(sl)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 22, 33, 1, 22, 33, 1, 22, 33]
# {1, 2, 3, 33, 22}

# %%
# set 자료형 순서없음, 인덱싱으로 요솟값을 얻을 수 없다.
s2 = set("Hello")
print(s2)
# Out:
# {'l', 'H', 'o', 'e'}

# %%
s1 = set([1, 2, 3])
l1 = list(s1)
print(l1)
print(l1[0])

t1 = tuple(s1)
print(t1)
print(t1[0])
# Out:
# [1, 2, 3]
# 1
# (1, 2, 3)
# 1

# %% [markdown]
# ## 집합 자료형 관련 함수

# %%
# add 집합자료형 값1개 추가

# %%
# update 집합자료형 값 여러개 추가하기
s1 = set([1, 2, 3])
print(s1)
s1.update([4, 5, 6])
print(s1)
# Out:
# {1, 2, 3}
# {1, 2, 3, 4, 5, 6}

# %%
# remove 집합 자료형 특정 값 제거하기
s1 = set([1,2,3])
print(s1)
s1.remove(2) # index가 아닌 값을 선택
print(s1)
# Out:
# {1, 2, 3}
# {1, 3}

# %%
# clear 집합자료형 내 모든 값 제거
s1 = set([1, 2, 3])
s1.clear()
print(s1)
# Out:
# set()

# %% [markdown]
# ## 불 자료형

# %%
# 기본
a = True
b = False
print(type(a),type(b))
# Out:
# <class 'bool'> <class 'bool'>

# %%
a = 7 > 4
print(a,type(a))

b = 13 < 4
print(b,type(b))

c = 13 == 4
print(c,type(c))

d = 13
# Out:
# True <class 'bool'>
# False <class 'bool'>
# False <class 'bool'>

# %% [markdown]
# <table>
# <thead>
# <tr>
# <th>값</th>
# <th>참 or 거짓</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>"python"</td>
# <td>참</td>
# </tr>
# <tr>
# <td>""</td>
# <td>거짓</td>
# </tr>
# <tr>
# <td>[1, 2, 3]</td>
# <td>참</td>
# </tr>
# <tr>
# <td>[]</td>
# <td>거짓</td>
# </tr>
# <tr>
# <td>(1, 2, 3)</td>
# <td>참</td>
# </tr>
# <tr>
# <td>()</td>
# <td>거짓</td>
# </tr>
# <tr>
# <td>{'a': 1}</td>
# <td>참</td>
# </tr>
# <tr>
# <td>{}</td>
# <td>거짓</td>
# </tr>
# <tr>
# <td>1</td>
# <td>참</td>
# </tr>
# <tr>
# <td>0</td>
# <td>거짓</td>
# </tr>
# <tr>
# <td>None</td>
# <td>거짓</td>
# </tr>
# </tbody>
# </table>

# %%
print(bool("python"))
print(bool(""))
print(bool([1,2,3]))
print(bool([]))
print(bool((1, 2, 3)))
print(bool(0))
print(bool({'a': 1}))
print(bool({}))
print(bool(1))
print(bool(0))
print(bool(None))
# Out:
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# False

# %% [markdown]
# ## 논리 연산자

# %%
# and 연산자
print("True and True: ->", True and True)
print("True and False: ->", True and False)
print("False and True: ->", False and True)
print("False and False: ->", False and False)
# Out:
# True and True: -> True
# True and False: -> False
# False and True: -> False
# False and False: -> False

# %%
# or 연산자
print("True or True: ->", True or True)
print("True or False: ->", True or False)
print("False or True: ->", False or True)
print("False or False: ->", False or False)
# Out:
# True or True: -> True
# True or False: -> True
# False or True: -> True
# False or False: -> False

# %%
# not 연산자
print("not True: ->",not True)
print("not False: ->",not False)
print("not 1: ->",not 1)
print("not 0: ->",not 0)
# Out:
# not True: -> False
# not False: -> True
# not 1: -> False
# not 0: -> True

# %%
print(bool("안녕"),bool(""))
print(not not "안녕", not not bool(""))
# Out:
# True False
# True False

# %% [markdown]
# ## 변수

# %% [markdown]
# ### 변수명 규칙
# 1. 영문자, 숫자, 언더스코어(_)만 사용할 수 있다.
# 2. 숫자로 시작할 수 없다.
# 3. 예약어는 사용할 수 없다.
# 4. 대소문자를 구분한다.

# %%
# snake_case(단어 사이에 언더스코어)

# 올바른 변수명 예시
name = "홍길동"
age = 25
user_name = "gildong"
userName = "gildong"  # 카멜 케이스
_private = "비공개"
count1 = 10

# 잘못된 변수명 예시
# 1name = "홍길동"    # 숫자로 시작 (오류)
# user-name = "홍길동"  # 하이픈 사용 (오류)
# if = 10             # 예약어 사용 (오류)

# %%
# id 메모리 주소확인
a = [1,2,3]
aa = a
b = [1,2,3]
print(id(a))
print(id(aa))
print(id(b))
# Out:
# 126486940968064
# 126486940968064
# 126486940961664

# %%
print(aa == a)
print(a == b)
print(aa is a)
print(a is b)
# Out:
# True
# True
# True
# False

# %%
e = [11,22,33]
ee = e
e[2] = 77
print(ee is e, ee, e)
# Out:
# True [11, 22, 77] [11, 22, 77]

# %%
e = [11,22,33]
ee = e[:]
e[2] = 77
print(ee is e, ee, e)
# Out:
# False [11, 22, 33] [11, 22, 77]

# %%
e = [11,22,33]
ee = e.copy()
e[2] = 77
print(ee is e, ee, e)
# Out:
# False [11, 22, 33] [11, 22, 77]

# %%
dir(e)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# ### 변수를 만드는 여러가지 방법

# %%
a , b = 123, 456
print(a)
print(b)
# Out:
# 123
# 456

# %%
[a, b, c] = ['python','life','cool']
print(a)
print(b)
print(c)
# Out:
# python
# life
# cool

# %%
a = b = c = 0
print(a)
print(b)
print(c)
# Out:
# 0
# 0
# 0

# %%
# 두 변수의 값을 바꿀 때 (*)
a = 33
b = 55
print(a, b)

a, b = b, a
print(a, b)
# Out:
# 33 55
# 55 33

# %%
# 다른언어에 temp
aa = 33
bb = 55
print(aa, bb)

temp = aa
aa = bb
bb = temp
print(aa, bb)
# Out:
# 33 55
# 55 33
